# %% [markdown]
# **Coin Flip Simulation** - Write some code that simulates flipping a single coin however many times the user decides. The code should record the outcomes and count the number of tails and heads.

# %%
def coin_flip_sim():

    # 0. Initialize code (imports and functions)

    from random import random
    from collections import Counter

    def flipper(amt):

        seq = []

        for n in range(amt):
            seq.append(round(random()))

        return seq

    def counter(seq):

        winners = Counter(seq)

        heads = winners[0]
        tails = winners[1]            

        return (heads,tails)

    def events_display(seq):
        for n, ind in enumerate(seq):
            if ind == 0:
                print('\tFlip # '+str(n+1)+' is a win for: Heads')
            elif ind == 1:
                print('\tFlip # '+str(n+1)+' is a win for: Tails')
        

    # 1. Ask if they would like to flip a coin: y or n
    
    start = ''
    while start != 'n' or start != 'y':
        start = input('Would you like to flip a coin? (y or n): ')
        if start == 'n':
            return False
        elif start == 'y':
            break

    # 2. Ask how many times would they like to flip it: integer
    
    while True:
        flips = input('How many times would you like to flip? (Please enter a number.) ')
        
        try:
            flips = int(flips)
            break
        except ValueError:
            print('\tSorry, that is not a number.')

    # 3. Run program using random()
    
    seq = flipper(flips)
    heads, tails = counter(seq)

    # 4. Print total results for heads and total results for tails

    print('\nHere are the results...\n')
    print('\tHeads won '+str(heads)+' times and tails won '+str(tails)+' times.')
    
    if heads > tails:
        print('\tHeads won!')
    elif tails > heads:
        print('\tTails won!')
    else:
        print('\tIt looks like it was a tie.')
    
    # 5. Print results for sequence of events (optional: condence results that are same in a row with a special notation)
    
    print('\nHere is how it all went down:\n')
    events_display(seq)
    
coin_flip_sim()
# Out:
# Would you like to flip a coin? (y or n): y
# How many times would you like to flip? (Please enter a number.) 100
#
# Here are the results...
#
# 	Heads won 42 times and tails won 58 times.
# 	Tails won!
#
# Here is how it all went down:
#
# 	Flip # 1 is a win for: Tails
# 	Flip # 2 is a win for: Heads
# 	Flip # 3 is a win for: Heads
# 	Flip # 4 is a win for: Heads
# 	Flip # 5 is a win for: Tails
# 	Flip # 6 is a win for: Tails
# 	Flip # 7 is a win for: Tails
# 	Flip # 8 is a win for: Tails
# 	Flip # 9 is a win for: Tails
# 	Flip # 10 is a win for: Heads
# 	Flip # 11 is a win for: Heads
# 	Flip # 12 is a win for: Tails
# 	Flip # 13 is a win for: Tails
# 	Flip # 14 is a win for: Tails
# 	Flip # 15 is a win for: Tails
# 	Flip # 16 is a win for: Heads
# 	Flip # 17 is a win for: Heads
# 	Flip # 18 is a win for: Heads
# 	Flip # 19 is a win for: Heads
# 	Flip # 20 is a win for: Heads
# 	Flip # 21 is a win for: Tails
# 	Flip # 22 is a win for: Tails
# 	Flip # 23 is a win for: Tails
# 	Flip # 24 is a win for: Tails
# 	Flip # 25 is a win for: Tails
# 	Flip # 26 is a win for: Tails
# 	Flip # 27 is a win for: Tails
